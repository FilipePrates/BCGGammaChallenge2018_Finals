# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from keras.layers import Dense
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras import metrics
from keras.models import load_model

from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Importando os modelos booleanos criados no keras para testar o que influencia mais ou menos o resultado

# %%
model_0709_bool = load_model(r'C:\Users\Filipe Prates\Documents\Projects\Datasets\BCG Challenge\original\models_keras\model_0709_bool.h5')
model_0911_bool = load_model(r'C:\Users\Filipe Prates\Documents\Projects\Datasets\BCG Challenge\original\models_keras\model_0911_bool.h5')
model_1113_bool = load_model(r'C:\Users\Filipe Prates\Documents\Projects\Datasets\BCG Challenge\original\models_keras\model_1113_bool.h5')
model_1315_bool = load_model(r'C:\Users\Filipe Prates\Documents\Projects\Datasets\BCG Challenge\original\models_keras\model_1315_bool.h5')

model_070911_bool = load_model(r'C:\Users\Filipe Prates\Documents\Projects\Datasets\BCG Challenge\original\models_keras\model_070911_bool.h5')
model_091113_bool = load_model(r'C:\Users\Filipe Prates\Documents\Projects\Datasets\BCG Challenge\original\models_keras\model_091113_bool.h5')
model_111315_bool = load_model(r'C:\Users\Filipe Prates\Documents\Projects\Datasets\BCG Challenge\original\models_keras\model_111315_bool.h5')

model_07091113_bool = load_model(r'C:\Users\Filipe Prates\Documents\Projects\Datasets\BCG Challenge\original\models_keras\model_07091113_bool.h5')
model_09111315_bool = load_model(r'C:\Users\Filipe Prates\Documents\Projects\Datasets\BCG Challenge\original\models_keras\model_09111315_bool.h5')

# %% [markdown]
# Import escolas médias

# %%
test_2anos_num = pd.read_csv(r'C:\Users\Filipe Prates\Documents\Projects\Datasets\BCG Challenge\original\test_models_2anos.csv')
test_2anos_bool = pd.read_csv(r'C:\Users\Filipe Prates\Documents\Projects\Datasets\BCG Challenge\original\tests\test_models_2anos_bool.csv')
test_3anos_bool = pd.read_csv(r'C:\Users\Filipe Prates\Documents\Projects\Datasets\BCG Challenge\original\tests\test_models_3anos_bool.csv')
test_4anos_bool = pd.read_csv(r'C:\Users\Filipe Prates\Documents\Projects\Datasets\BCG Challenge\original\tests\test_models_4anos_bool.csv')

# %% [markdown]
# Import escolas teste

# %%
test_2anos_bool
# Out:
#    in_comum_creche0  in_comum_pre0  in_comum_fund_ai0  in_comum_fund_af0  \
# 0             False          False               True               True
#
#    in_comum_medio_integrado0  in_comum_medio_normal0  in_comum_medio_medio0  \
# 0                      False                   False                  False
#
#    in_em_atividade0  in_local_func_predio_escolar0  \
# 0              True                           True
#
#    in_local_func_salas_empresa0        ...         in_alojam_aluno1  \
# 0                         False        ...                    False
#
#    in_alojam_professor1  in_area_verde1  in_lavanderia1  in_internet1  \
# 0                 False           False           False          True
#
#    in_banda_larga1  in_alimentacao1  in_educacao_indigena1  \
# 0             True             True                  False
#
#    in_brasil_alfabetizado1  in_final_semana1
# 0                    False             False
#
# [1 rows x 145 columns]

# %%
print((model_0709_bool.predict(test_2anos_bool)+model_0911_bool.predict(test_2anos_bool)+model_1113_bool.predict(test_2anos_bool)+model_1315_bool.predict(test_2anos_bool))/4)
# Out:
# [[5.629962]]

# %% [markdown]
# Para cada coluna da 'escola media' booleana, trocar o valor da coluna, e prever o Ideb usando o ensemble de 2 anos. Printar o resultando e a diferença da 'escola media'

# %%
print((model_0709_bool.predict(test_2anos_bool)+model_0911_bool.predict(test_2anos_bool)+model_1113_bool.predict(test_2anos_bool)+model_1315_bool.predict(test_2anos_bool))/4)
for c in test_2anos_bool:
    if (c != 'Ideb2015' and c != 'Ideb2017'):
        test_2anos_bool[c] = not test_2anos_bool[c].any()
        print(c, test_2anos_bool[c].any(),(model_0709_bool.predict(test_2anos_bool)+model_0911_bool.predict(test_2anos_bool)+model_1113_bool.predict(test_2anos_bool)+model_1315_bool.predict(test_2anos_bool))/4)
        print('dif: ',(model_0709_bool.predict(test_2anos_bool)+model_0911_bool.predict(test_2anos_bool)+model_1113_bool.predict(test_2anos_bool)+model_1315_bool.predict(test_2anos_bool))/4 - 5.629962)
        test_2anos_bool[c] = not test_2anos_bool[c].any()
# Out:
# [[5.578291]]
# in_comum_creche0 True [[5.6047974]]
# dif:  [[-0.0251646]]
# in_comum_pre0 True [[5.6297956]]
# dif:  [[-0.00016642]]
# in_comum_fund_ai0 False [[5.5326805]]
# dif:  [[-0.09728146]]
# in_comum_fund_af0 False [[5.597683]]
# dif:  [[-0.03227901]]
# in_comum_medio_integrado0 True [[5.574035]]
# dif:  [[-0.0559268]]
# in_comum_medio_normal0 True [[5.6178894]]
# dif:  [[-0.01207256]]
# in_comum_medio_medio0 True [[5.593664]]
# dif:  [[-0.0362978]]
# in_em_atividade0 False [[5.461446]]
# dif:  [[-0.16851616]]
# in_local_func_predio_escolar0 False [[5.5435085]]
# dif:  [[-0.08645344]]
# in_local_func_salas_empresa0 True [[5.6588144]]
# dif:  [[0.02885246]]
# in_local_func_socioeducativo0 True [[5.5124393]]
# dif:  [[-0.11752272]]
# in_local_func_unid_prisional0 True [[5.5197873]]
# dif:  [[-0.11017466]]
# in_local_func_prisional_socio0 True [[5.548035]]
# dif:  [[-0.08192682]]
# in_local_func_templo_igreja0 True [[5.590557]]
# dif:  [[-0.03940487]]
# ...

# %% [markdown]
# Mesma ideia pros modelos de 3 anos

# %%
print((model_070911_bool.predict(test_3anos_bool)+model_091113_bool.predict(test_3anos_bool)+model_111315_bool.predict(test_3anos_bool))/3)

# %%
print((model_070911_bool.predict(test_3anos_bool)+model_091113_bool.predict(test_3anos_bool)+model_111315_bool.predict(test_3anos_bool))/3)
for c in test_2anos_bool:
    if (c != 'Ideb2015' and c != 'Ideb2017' and c != 'Ideb2016'):
        test_3anos_bool[c] = not test_3anos_bool[c].any()
        print(c, test_3anos_bool[c].any(),(model_070911_bool.predict(test_3anos_bool)+model_091113_bool.predict(test_3anos_bool)+model_111315_bool.predict(test_3anos_bool))/3)
        print('dif: ',(model_070911_bool.predict(test_3anos_bool)+model_091113_bool.predict(test_3anos_bool)+model_111315_bool.predict(test_3anos_bool))/3 - 5.947815)
        test_3anos_bool[c] = not test_3anos_bool[c].any()
# Out:
# [[5.947815]]
# in_comum_creche0 True [[5.9923577]]
# dif:  [[0.04454279]]
# in_comum_pre0 True [[6.0171285]]
# dif:  [[0.06931353]]
# in_comum_fund_ai0 False [[5.9854217]]
# dif:  [[0.03760672]]
# in_comum_fund_af0 False [[5.95818]]
# dif:  [[0.01036501]]
# in_comum_medio_integrado0 True [[5.9617867]]
# dif:  [[0.01397181]]
# in_comum_medio_normal0 True [[5.9129777]]
# dif:  [[-0.03483725]]
# in_comum_medio_medio0 True [[5.9549384]]
# dif:  [[0.00712347]]
# in_em_atividade0 False [[5.905001]]
# dif:  [[-0.04281378]]
# in_local_func_predio_escolar0 False [[5.9333305]]
# dif:  [[-0.01448441]]
# in_local_func_salas_empresa0 True [[6.0070286]]
# dif:  [[0.05921364]]
# in_local_func_socioeducativo0 True [[5.915853]]
# dif:  [[-0.03196192]]
# in_local_func_unid_prisional0 True [[5.8898735]]
# dif:  [[-0.05794144]]
# in_local_func_prisional_socio0 True [[5.963119]]
# dif:  [[0.01530409]]
# in_local_func_templo_igreja0 True [[5.96917]]
# dif:  [[0.02135515]]
# ...

# %% [markdown]
# Mesma ideia modelos 4 anos

# %%
print((model_07091113_bool.predict(test_4anos_bool)+model_09111315_bool.predict(test_4anos_bool))/2)

# %%
print((model_07091113_bool.predict(test_4anos_bool)+model_09111315_bool.predict(test_4anos_bool))/2)
for c in test_4anos_bool:
    if (c != 'Ideb2015' and c != 'Ideb2017' and c != 'Ideb2016' and c != 'Ideb2013'):
        test_4anos_bool[c] = not test_4anos_bool[c].any()
        print(c, test_4anos_bool[c].any(),(model_07091113_bool.predict(test_4anos_bool)+model_09111315_bool.predict(test_4anos_bool))/2)
        print('dif: ',(model_07091113_bool.predict(test_4anos_bool)+model_09111315_bool.predict(test_4anos_bool))/2 - 6.0305898)
        test_4anos_bool[c] = not test_4anos_bool[c].any()
# Out:
# [[6.035898]]
# in_comum_creche0 True [[6.052827]]
# dif:  [[0.0222373]]
# in_comum_pre0 True [[5.999552]]
# dif:  [[-0.03103781]]
# in_comum_fund_ai0 False [[6.0243864]]
# dif:  [[-0.00620317]]
# in_comum_fund_af0 False [[6.0191393]]
# dif:  [[-0.01145029]]
# in_comum_medio_integrado0 True [[6.036726]]
# dif:  [[0.00613642]]
# in_comum_medio_normal0 True [[6.038211]]
# dif:  [[0.00762129]]
# in_comum_medio_medio0 True [[6.0307016]]
# dif:  [[0.00011206]]
# in_em_atividade0 False [[5.996747]]
# dif:  [[-0.03384256]]
# in_local_func_predio_escolar0 False [[6.018033]]
# dif:  [[-0.01255655]]
# in_local_func_salas_empresa0 True [[6.0329633]]
# dif:  [[0.0023737]]
# in_local_func_socioeducativo0 True [[6.069619]]
# dif:  [[0.0390296]]
# in_local_func_unid_prisional0 True [[5.9691105]]
# dif:  [[-0.06147909]]
# in_local_func_prisional_socio0 True [[6.0243807]]
# dif:  [[-0.0062089]]
# in_local_func_templo_igreja0 True [[6.024539]]
# dif:  [[-0.00605059]]
# ...

# %% [markdown]
# Podemos ver que as varíaveis de Quadra Esporte, Agua_Rede Pública, e Coleta de Lixo Periódica influenciam bastante os modelos, que bate com as analises feitas pelos outros participantes dos grupos também observamos a importância de internet e banda larga nos modelos.
#
# Vale também mencionar que alguns resultados não fazem tanto sentido, com resultados não intuitivos. A explicação de tais resultados é o fato que nessas variáveis temos um quantidade muito grande da base de treinamento com o mesmo valor, então a rede mal aprendeu a influência da tal no resultado do modelo
